# %%
import pandas as pd
import numpy as np

# %%
tengen_df = pd.read_csv(r'C:\SEM5\tempWorkspace\apurvinho\resources\tengen2.csv')

# %%
tengen_df[tengen_df['Title'].str.contains('[cC]plusplus')]
# Out:
#       Unnamed: 0  BookIndex  Accession Number  \
# 17            17         17            2875.0
# 71            71         71            4405.0
# 90            90         90            7044.0
# 91            91         91            7183.0
# 112          112        112            9241.0
# ...          ...        ...               ...
# 9035        9035       9035               NaN
# 9038        9038       9038               NaN
# 9044        9044       9044               NaN
# 9074        9074       9074               NaN
# 9075        9075       9075               NaN
#
#                                                  Author  \
# 17                                       Thareja, Reema
# 71                                       Lafore, Robert
# 90                        Grewal, B. S. & Grewal, J. S.
# 91                                         Wadhwa, Ajay
# 112   Langsam, Yedidyah & Augenstein, Moshe J. & Ten...
# ...                                                 ...
# 9035                                            unknown
# 9038                                            unknown
# 9044                                            unknown
# 9074                                            unknown
# 9075                                            unknown
#
#                                                   Title  \
# 17           Object Oriented Programming With cplusplus
# 71             Object Oriented Programming In cplusplus
# 90    Numerical Methods: In Engineering & Science, W...
# 91    Numerical Analysis: With Algorithms And Comput...
# 112               Data Structures Using C And cplusplus
# ...                                                 ...
# 9035            cplusplus Templates: The Complete Guide
# 9038                  Inside the cplusplus Object Model
# 9044  Optimized cplusplus: Proven Techniques for Hei...
# 9074  File Structures: An Object-Oriented Approach w...
# 9075  The cplusplus Standard Library: A Tutorial and...
#
#                          Publisher           ISBN     Subject  \
# 17         Oxford University Press  9780199459636    Computer
# 71              Pearson, New Delhi  9788131722824    Computer
# 90    Khanna Publishers, New Delhi  9788174092489  Mechanical
# 91         PHI Learning, New Delhi  9788120345454    Computer
# 112        PHI Learning, New Delhi  9788120311770    Computer
# ...                            ...            ...         ...
# 9035                           NaN            NaN         NaN
# 9038                           NaN            NaN         NaN
# 9044                           NaN            NaN         NaN
# 9074                           NaN            NaN         NaN
# 9075                           NaN            NaN         NaN
#
#                                                   combo  \
# 17    Object Oriented Programming With cplusplus Tha...
# 71    Object Oriented Programming In cplusplus Lafor...
# 90    Numerical Methods: In Engineering & Science, W...
# 91    Numerical Analysis: With Algorithms And Comput...
# 112   Data Structures Using C And cplusplus Langsam,...
# ...                                                 ...
# 9035  cplusplus Templates: The Complete Guide Templa...
# 9038  Inside the cplusplus Object Model Aimed at the...
# 9044  Optimized cplusplus: Proven Techniques for Hei...
# 9074  File Structures: An Object-Oriented Approach w...
# 9075  The cplusplus Standard Library: A Tutorial and...
#
#                              mycategories  ...  \
# 17                 cplusplus, programming  ...
# 71                 cplusplus, programming  ...
# 90                              cplusplus  ...
# 91    cplusplus, datastructuresalgorithms  ...
# 112   cplusplus, datastructuresalgorithms  ...
# ...                                   ...  ...
# 9035       cplusplus, softwareengineering  ...
# 9038                            cplusplus  ...
# 9044                            cplusplus  ...
# 9074       cplusplus, softwareengineering  ...
# 9075                            cplusplus  ...
#
#                                             Description  Rating        Price  \
# 17                                                  NaN    3.99          NaN
# 71                                                  NaN    2.87          NaN
# 90                                                  NaN    2.96          NaN
# 91                                                  NaN    2.59          NaN
# 112                                                 NaN    3.13          NaN
# ...                                                 ...     ...          ...
# 9035  Templates are among the most powerful features...    4.24         79.1
# 9038  Aimed at the beginner/intermediate cplusplus p...    4.25  80.84411765
# 9044  In today's fast and competitive world, a progr...    3.48        83.15
# 9074  Based on the bestselling File Structures, Seco...    3.87  108.3676471
# 9075  The Best-Selling cplusplus ResourceNow Updated...    4.16  113.3029412
#
#       Thumbnail PreviewURL publishedDate InfoURL Reviews Number_Of_Pages  \
# 17          NaN        NaN           NaN     NaN     NaN             NaN
# 71          NaN        NaN           NaN     NaN     NaN             NaN
# 90          NaN        NaN           NaN     NaN     NaN             NaN
# 91          NaN        NaN           NaN     NaN     NaN             NaN
# 112         NaN        NaN           NaN     NaN     NaN             NaN
# ...         ...        ...           ...     ...     ...             ...
# 9035        NaN        NaN           NaN     NaN      11           560.0
# 9038        NaN        NaN           NaN     NaN       3           304.0
# 9044        NaN        NaN           NaN     NaN       3           388.0
# 9074        NaN        NaN           NaN     NaN      13           724.0
# 9075        NaN        NaN           NaN     NaN      16          1136.0
#
#            Type
# 17         Book
# 71         Book
# 90         Book
# 91         Book
# 112        Book
# ...         ...
# 9035  Hardcover
# 9038  Paperback
# 9044  Paperback
# 9074  Paperback
# 9075  Hardcover
#
# [223 rows x 22 columns]

# %%
tengen_df_2 = tengen_df

# %%
tengen_df_2['Title'].replace(r'[cC]plusplus', 'C++', regex=True, inplace=True)
tengen_df_2['Title'].replace(r'[cC]sharp', 'C#', regex=True, inplace=True)

# %%
tengen_df_2
# Out:
#       Unnamed: 0  BookIndex  Accession Number  \
# 0              0          0             786.0
# 1              1          1             836.0
# 2              2          2            1437.0
# 3              3          3            1771.0
# 4              4          4            2417.0
# ...          ...        ...               ...
# 9083        9083       9083               NaN
# 9084        9084       9084               NaN
# 9085        9085       9085               NaN
# 9086        9086       9086               NaN
# 9087        9087       9087               NaN
#
#                                     Author  \
# 0     Kernighan, Brian W. & Ritchie, D. M.
# 1                          Dreamtech Press
# 2                         Schildt, Herbert
# 3                               Lutz, Mark
# 4                             Cowley, John
# ...                                    ...
# 9083                               unknown
# 9084                               unknown
# 9085                               unknown
# 9086                               unknown
# 9087                               unknown
#
#                                                   Title             Publisher  \
# 0                                C Programming Language       Pearson,Chennai
# 1                                     Html 5 Black Book   Dreamtech,New Delhi
# 2                           Java The Complete Reference  Mc Graw Hill Chennai
# 3                                       Learning Python       O'Reilly,Mumbai
# 4                         Communications And Networking              Springer
# ...                                                 ...                   ...
# 9083  3D Game Engine Architecture: Engineering Real-...                   NaN
# 9084                An Introduction to Database Systems                   NaN
# 9085  The Art of Computer Programming, Volumes 1-3 B...                   NaN
# 9086  The Art of Computer Programming, Volumes 1-4a ...                   NaN
# 9087              A Discipline for Software Engineering                   NaN
#
#                ISBN   Subject  \
# 0     9789332549449  Computer
# 1     9789351199076  Computer
# 2     9789339212094  Computer
# 3     9789351102014  Computer
# 4     9788184894394    E & TC
# ...             ...       ...
# 9083            NaN       NaN
# 9084            NaN       NaN
# 9085            NaN       NaN
# 9086            NaN       NaN
# 9087            NaN       NaN
#
#                                                   combo  \
# 0     C Programming Language Kernighan, Brian W. & R...
# 1     Html 5 Black Book Dreamtech Press Dreamtech,Ne...
# 2     Java The Complete Reference Schildt, Herbert M...
# 3            Learning Python Lutz, Mark O'Reilly,Mumbai
# 4     Communications And Networking Cowley, John Spr...
# ...                                                 ...
# 9083  3D Game Engine Architecture: Engineering Real-...
# 9084  An Introduction to Database Systems Continuing...
# 9085  The Art of Computer Programming, Volumes 1-3 B...
# 9086  The Art of Computer Programming, Volumes 1-4a ...
# 9087  A Discipline for Software Engineering Designed...
#
#                                            mycategories  ...  \
# 0                                           programming  ...
# 1                                                  html  ...
# 2                                                  java  ...
# 3                                                python  ...
# 4                                      computernetworks  ...
# ...                                                 ...  ...
# 9083  programming, softwareengineering, datastructur...  ...
# 9084                                           database  ...
# 9085                                        programming  ...
# 9086  programming, softwareengineering, datastructur...  ...
# 9087                                softwareengineering  ...
#
#                                             Description  Rating        Price  \
# 0                                                   NaN    4.43          NaN
# 1                                                   NaN    2.71          NaN
# 2                                                   NaN    3.12          NaN
# 3                                                   NaN    4.41          NaN
# 4                                                   NaN    4.87          NaN
# ...                                                 ...     ...          ...
# 9083  Dave Eberly's 3D Game Engine Design was the fi...    3.76  203.1088235
# 9084  Continuing in the eighth edition, An Introduct...    3.94  212.0970588
# 9085  Knuth's classic work has been widely acclaimed...    4.49  220.3852941
# 9086  "The bible of all fundamental algorithms and t...    4.77  220.3852941
# 9087  Designed to help individual programmers develo...    3.84       235.65
#
#       Thumbnail PreviewURL publishedDate InfoURL Reviews Number_Of_Pages  \
# 0           NaN        NaN           NaN     NaN     NaN             NaN
# 1           NaN        NaN           NaN     NaN     NaN             NaN
# 2           NaN        NaN           NaN     NaN     NaN             NaN
# 3           NaN        NaN           NaN     NaN     NaN             NaN
# 4           NaN        NaN           NaN     NaN     NaN             NaN
# ...         ...        ...           ...     ...     ...             ...
# 9083        NaN        NaN           NaN     NaN       0           752.0
# 9084        NaN        NaN           NaN     NaN      22          1040.0
# 9085        NaN        NaN           NaN     NaN      36           896.0
# 9086        NaN        NaN           NaN     NaN       4          3168.0
# 9087        NaN        NaN           NaN     NaN       5           789.0
#
#                        Type
# 0                      Book
# 1                      Book
# 2                      Book
# 3                      Book
# 4                      Book
# ...                     ...
# 9083              Hardcover
# 9084              Paperback
# 9085  Boxed Set - Hardcover
# 9086              Hardcover
# 9087              Hardcover
#
# [9088 rows x 22 columns]

# %%
tengen_df_2[tengen_df_2['Title'].str.contains(r'[cC]\+\+')]
# Out:
#       Unnamed: 0  BookIndex  Accession Number  \
# 17            17         17            2875.0
# 71            71         71            4405.0
# 90            90         90            7044.0
# 91            91         91            7183.0
# 112          112        112            9241.0
# ...          ...        ...               ...
# 9035        9035       9035               NaN
# 9038        9038       9038               NaN
# 9044        9044       9044               NaN
# 9074        9074       9074               NaN
# 9075        9075       9075               NaN
#
#                                                  Author  \
# 17                                       Thareja, Reema
# 71                                       Lafore, Robert
# 90                        Grewal, B. S. & Grewal, J. S.
# 91                                         Wadhwa, Ajay
# 112   Langsam, Yedidyah & Augenstein, Moshe J. & Ten...
# ...                                                 ...
# 9035                                            unknown
# 9038                                            unknown
# 9044                                            unknown
# 9074                                            unknown
# 9075                                            unknown
#
#                                                   Title  \
# 17                 Object Oriented Programming With C++
# 71                   Object Oriented Programming In C++
# 90    Numerical Methods: In Engineering & Science, W...
# 91    Numerical Analysis: With Algorithms And Comput...
# 112                     Data Structures Using C And C++
# ...                                                 ...
# 9035                  C++ Templates: The Complete Guide
# 9038                        Inside the C++ Object Model
# 9044  Optimized C++: Proven Techniques for Heightene...
# 9074  File Structures: An Object-Oriented Approach w...
# 9075  The C++ Standard Library: A Tutorial and Refer...
#
#                          Publisher           ISBN     Subject  \
# 17         Oxford University Press  9780199459636    Computer
# 71              Pearson, New Delhi  9788131722824    Computer
# 90    Khanna Publishers, New Delhi  9788174092489  Mechanical
# 91         PHI Learning, New Delhi  9788120345454    Computer
# 112        PHI Learning, New Delhi  9788120311770    Computer
# ...                            ...            ...         ...
# 9035                           NaN            NaN         NaN
# 9038                           NaN            NaN         NaN
# 9044                           NaN            NaN         NaN
# 9074                           NaN            NaN         NaN
# 9075                           NaN            NaN         NaN
#
#                                                   combo  \
# 17    Object Oriented Programming With cplusplus Tha...
# 71    Object Oriented Programming In cplusplus Lafor...
# 90    Numerical Methods: In Engineering & Science, W...
# 91    Numerical Analysis: With Algorithms And Comput...
# 112   Data Structures Using C And cplusplus Langsam,...
# ...                                                 ...
# 9035  cplusplus Templates: The Complete Guide Templa...
# 9038  Inside the cplusplus Object Model Aimed at the...
# 9044  Optimized cplusplus: Proven Techniques for Hei...
# 9074  File Structures: An Object-Oriented Approach w...
# 9075  The cplusplus Standard Library: A Tutorial and...
#
#                              mycategories  ...  \
# 17                 cplusplus, programming  ...
# 71                 cplusplus, programming  ...
# 90                              cplusplus  ...
# 91    cplusplus, datastructuresalgorithms  ...
# 112   cplusplus, datastructuresalgorithms  ...
# ...                                   ...  ...
# 9035       cplusplus, softwareengineering  ...
# 9038                            cplusplus  ...
# 9044                            cplusplus  ...
# 9074       cplusplus, softwareengineering  ...
# 9075                            cplusplus  ...
#
#                                             Description  Rating        Price  \
# 17                                                  NaN    3.99          NaN
# 71                                                  NaN    2.87          NaN
# 90                                                  NaN    2.96          NaN
# 91                                                  NaN    2.59          NaN
# 112                                                 NaN    3.13          NaN
# ...                                                 ...     ...          ...
# 9035  Templates are among the most powerful features...    4.24         79.1
# 9038  Aimed at the beginner/intermediate cplusplus p...    4.25  80.84411765
# 9044  In today's fast and competitive world, a progr...    3.48        83.15
# 9074  Based on the bestselling File Structures, Seco...    3.87  108.3676471
# 9075  The Best-Selling cplusplus ResourceNow Updated...    4.16  113.3029412
#
#       Thumbnail PreviewURL publishedDate InfoURL Reviews Number_Of_Pages  \
# 17          NaN        NaN           NaN     NaN     NaN             NaN
# 71          NaN        NaN           NaN     NaN     NaN             NaN
# 90          NaN        NaN           NaN     NaN     NaN             NaN
# 91          NaN        NaN           NaN     NaN     NaN             NaN
# 112         NaN        NaN           NaN     NaN     NaN             NaN
# ...         ...        ...           ...     ...     ...             ...
# 9035        NaN        NaN           NaN     NaN      11           560.0
# 9038        NaN        NaN           NaN     NaN       3           304.0
# 9044        NaN        NaN           NaN     NaN       3           388.0
# 9074        NaN        NaN           NaN     NaN      13           724.0
# 9075        NaN        NaN           NaN     NaN      16          1136.0
#
#            Type
# 17         Book
# 71         Book
# 90         Book
# 91         Book
# 112        Book
# ...         ...
# 9035  Hardcover
# 9038  Paperback
# 9044  Paperback
# 9074  Paperback
# 9075  Hardcover
#
# [223 rows x 22 columns]

# %%
mongo_books_csv = tengen_df_2.to_csv(r'C:\SEM5\tempWorkspace\apurvinho\resources\mongo_books.csv')
